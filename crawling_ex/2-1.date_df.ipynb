# %%
import pandas as pd

# %%
df = pd.read_csv("naver_news/2025-11-17-15.csv")
df.head()
# Out:
#   "OLED로 면적당 판가 30% 껑충"...LG디스플레이, 프리미엄 제품 전략 통했다  파이낸셜뉴스  \
# 0                지난해 자가보유율 61.4%…주택 가격은 연소득의 6.3배     KBS
# 1              李 대통령 "대미 투자 강화돼도 국내 투자 줄지 않게 해달라"  아이뉴스24
# 2                   금감원, 증권사 모험자본 공급 역량 강화 워크숍 개최     머니S
# 3             LG엔솔, 국내 ESS용 LFP 생산 나선다…"2027년 가동"     뉴시스
# 4             中企 재직자 '5년 4천만원 적립' 저축공제, 참여은행 확대한다     뉴스1
#
#   https://mimgnews.pstatic.net/image/origin/014/2025/11/17/5435408.jpg
# 0  https://mimgnews.pstatic.net/image/origin/056/...
# 1  https://mimgnews.pstatic.net/image/origin/031/...
# 2  https://mimgnews.pstatic.net/image/origin/417/...
# 3  https://mimgnews.pstatic.net/image/origin/003/...
# 4  https://mimgnews.pstatic.net/image/origin/421/...
